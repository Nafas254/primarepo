# %%
import pandas as pd

df=pd.read_csv("energia.csv")
df
# Out:
#     ITTER107 Territorio  TIPO_DATO_CENERG  \
# 0         IT     Italia     ENER_SOUR_EXP
# 1         IT     Italia     ENER_SOUR_EXP
# 2         IT     Italia     ENER_SOUR_EXP
# 3         IT     Italia     ENER_SOUR_EXP
# 4         IT     Italia     ENER_SOUR_EXP
# ..       ...        ...               ...
# 296     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 297     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 298     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 299     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 300     ITG2   Sardegna  ENER_SOUR_EXP_AV
#
#                                              Tipo dato DOTAZIONI_A  \
# 0    spese delle famiglie per consumi energetici pe...         ALL
# 1    spese delle famiglie per consumi energetici pe...       H_OIL
# 2    spese delle famiglie per consumi energetici pe...         LPG
# 3    spese delle famiglie per consumi energetici pe...      ELECTR
# 4    spese delle famiglie per consumi energetici pe...       METAN
# ...

# %%
df.Territorio.value_counts()
# Out:
# Italia                                17
# Toscana                               11
# Sicilia                               11
# Calabria                              11
# Basilicata                            11
# Puglia                                11
# Campania                              11
# Molise                                11
# Abruzzo                               11
# Mezzogiorno                           11
# Lazio                                 11
# Marche                                11
# Umbria                                11
# Centro                                11
# Nord-ovest                            11
# Emilia-Romagna                        11
# Friuli-Venezia Giulia                 11
# Veneto                                11
# Provincia Autonoma Trento             11
# Provincia Autonoma Bolzano / Bozen    11
# Trentino Alto Adige / Südtirol        11
# Nord-est                              11
# Lombardia                             11
# ...

# %%
Territori=df['Territorio'].unique().tolist()
Territori
# Out:
# ['Italia',
#  'Nord-ovest',
#  'Piemonte',
#  "Valle d'Aosta / Vallée d'Aoste",
#  'Liguria',
#  'Lombardia',
#  'Nord-est',
#  'Trentino Alto Adige / Südtirol',
#  'Provincia Autonoma Bolzano / Bozen',
#  'Provincia Autonoma Trento',
#  'Veneto',
#  'Friuli-Venezia Giulia',
#  'Emilia-Romagna',
#  'Centro',
#  'Toscana',
#  'Umbria',
#  'Marche',
#  'Lazio',
#  'Mezzogiorno',
#  'Abruzzo',
#  'Molise',
#  'Campania',
#  'Puglia',
#  'Basilicata',
#  'Calabria',
#  'Sicilia',
#  'Sardegna']

# %%
dict_territori={
 "Valle d'Aosta / Vallée d'Aoste":"Valle d Aosta",
 'Trentino Alto Adige / Südtirol':'Trentino Alto Adige',
 'Provincia Autonoma Bolzano / Bozen':'Provincia Autonoma Bolzano',
 'Provincia Autonoma Trento':'Provincia Autonoma Trento',
 'Friuli-Venezia Giulia':'Friuli Venezia Giulia','Nord-ovest':'Nord Ovest','Emilia-Romagna':'Emilia Romagna','Nord-est':'Nord est'}
df.Territorio
# Out:
# 0        Italia
# 1        Italia
# 2        Italia
# 3        Italia
# 4        Italia
#          ...
# 296    Sardegna
# 297    Sardegna
# 298    Sardegna
# 299    Sardegna
# 300    Sardegna
# Name: Territorio, Length: 301, dtype: object

# %%
df=df.replace({'Territorio':dict_territori})
Territori=df['Territorio'].unique().tolist()
Territori
# Out:
# ['Italia',
#  'Nord Ovest',
#  'Piemonte',
#  'Valle d Aosta',
#  'Liguria',
#  'Lombardia',
#  'Nord est',
#  'Trentino Alto Adige',
#  'Provincia Autonoma Bolzano',
#  'Provincia Autonoma Trento',
#  'Veneto',
#  'Friuli Venezia Giulia',
#  'Emilia Romagna',
#  'Centro',
#  'Toscana',
#  'Umbria',
#  'Marche',
#  'Lazio',
#  'Mezzogiorno',
#  'Abruzzo',
#  'Molise',
#  'Campania',
#  'Puglia',
#  'Basilicata',
#  'Calabria',
#  'Sicilia',
#  'Sardegna']

# %%
for i in Territori:
    df.loc[df.Territorio==i,:].to_csv(f'CSV_files/{i}.csv', index=False)
    print(df.loc[df.Territorio==i,:])
# Out:
#    ITTER107 Territorio   TIPO_DATO_CENERG  \
# 0        IT     Italia      ENER_SOUR_EXP
# 1        IT     Italia      ENER_SOUR_EXP
# 2        IT     Italia      ENER_SOUR_EXP
# 3        IT     Italia      ENER_SOUR_EXP
# 4        IT     Italia      ENER_SOUR_EXP
# 5        IT     Italia   ENER_SOUR_EXP_AV
# 6        IT     Italia   ENER_SOUR_EXP_AV
# 7        IT     Italia   ENER_SOUR_EXP_AV
# 8        IT     Italia   ENER_SOUR_EXP_AV
# 9        IT     Italia   ENER_SOUR_EXP_AV
# 10       IT     Italia   ENER_SOUR_EXP_AV
# 11       IT     Italia  ENER_SOUR_EXP_MED
# 12       IT     Italia  ENER_SOUR_EXP_MED
# 13       IT     Italia  ENER_SOUR_EXP_MED
# 14       IT     Italia  ENER_SOUR_EXP_MED
# 15       IT     Italia  ENER_SOUR_EXP_MED
# 16       IT     Italia  ENER_SOUR_EXP_MED
#
#                                             Tipo dato DOTAZIONI_A  \
# 0   spese delle famiglie per consumi energetici pe...         ALL
# ...

# %%
for i in Territori:
    df.loc[df.Territorio==i,:].to_excel(f'xlsx_files/{i}.xlsx', index=False)
    print(df.loc[df.Territorio==i,:])
# Out:
#    ITTER107 Territorio   TIPO_DATO_CENERG  \
# 0        IT     Italia      ENER_SOUR_EXP
# 1        IT     Italia      ENER_SOUR_EXP
# 2        IT     Italia      ENER_SOUR_EXP
# 3        IT     Italia      ENER_SOUR_EXP
# 4        IT     Italia      ENER_SOUR_EXP
# 5        IT     Italia   ENER_SOUR_EXP_AV
# 6        IT     Italia   ENER_SOUR_EXP_AV
# 7        IT     Italia   ENER_SOUR_EXP_AV
# 8        IT     Italia   ENER_SOUR_EXP_AV
# 9        IT     Italia   ENER_SOUR_EXP_AV
# 10       IT     Italia   ENER_SOUR_EXP_AV
# 11       IT     Italia  ENER_SOUR_EXP_MED
# 12       IT     Italia  ENER_SOUR_EXP_MED
# 13       IT     Italia  ENER_SOUR_EXP_MED
# 14       IT     Italia  ENER_SOUR_EXP_MED
# 15       IT     Italia  ENER_SOUR_EXP_MED
# 16       IT     Italia  ENER_SOUR_EXP_MED
#
#                                             Tipo dato DOTAZIONI_A  \
# 0   spese delle famiglie per consumi energetici pe...         ALL
# ...
